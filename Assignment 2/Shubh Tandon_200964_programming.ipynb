# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')

# %%
data=pd.read_excel(r'/content/gdrive/My Drive/Copy of Guj_AC_009.xlsx')

# %%
pt=pd.DataFrame(data)
display(pd.DataFrame(data))
# Out:
#        ACNo  PartNo  SectionNo  SNo HouseNoEn VoterFirstNameEn  \
# 0         9       1          1    1         1          MINABEN
# 1         9       1          1    2       1-1        PUNMABHAI
# 2         9       1          1    3       1-1          SITABEN
# 3         9       1          1    4       1-1      PRAKASHBHAI
# 4         9       1          1    5       1-2       ISHVARBHAI
# ...     ...     ...        ...  ...       ...              ...
# 92566     9     100          3  886        51        SHILPABEN
# 92567     9     100          3  887      51 એ      JIGNESHBHAI
# 92568     9     100          7  888        97         Vijyaben
# 92569     9     100          1  889        23        LALITABEN
# 92570     9     100          1  890        26          Ashaben
#
#       VoterLastNameEn VoterFirstame VoterLastName RelationType  ... Age  \
# 0             THAKKAR       મીનાબેન         ઠક્કર            H  ...  44
# ...

# %%
print(data['ContactNo'].value_counts())
# Out:
# 0                4113
# +91               558
# 7567458808        375
# 9821554129        248
# 9879594207        181
#                  ...
# 8980458243          1
# 2748234631          1
# 9898164664          1
# 7874259315          1
# +919978280605       1
# Name: ContactNo, Length: 15730, dtype: int64

# %%
print(len(data))
# Out:
# 92571

# %%
female=pt['RelationType'].value_counts()['F']
print("Female voters are",pt['RelationType'].value_counts()['F'])
# Out:
# Female voters are 52578

# %%
male=pt['RelationType'].value_counts()['H']
print("male voters count=",male)
# Out:
# male voters count= 39749

# %%
plt.hist(data['RelationType'])
plt.show()

# %%
first=pt['Age'].value_counts()[23]+pt['Age'].value_counts()[22]+pt['Age'].value_counts()[21]+pt['Age'].value_counts()[20]+pt['Age'].value_counts()[19]
print("count of First time voter=",pt['Age'].value_counts()[23]+pt['Age'].value_counts()[22]+pt['Age'].value_counts()[21]+pt['Age'].value_counts()[20]+pt['Age'].value_counts()[19])
# Out:
# count of First time voter= 10745

# %%
print("percentage of 1st time voter",first/len(data)*100,"%")
# Out:
# percentage of 1st time voter 11.607306823951346 %
